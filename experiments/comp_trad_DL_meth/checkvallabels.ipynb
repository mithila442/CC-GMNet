# %%
import pandas as pd
import os

path = "/media/nas/pgonzalez/lequa2024/T2/public"

prevalences=pd.read_csv(os.path.join(path,'dev_prevalences.txt'))
prevalences
# Out:
#       id      0      1      2      3      4      5      6      7      8  ...  \
# 0      0  0.030  0.038  0.021  0.017  0.032  0.008  0.043  0.017  0.020  ...
# 1      1  0.073  0.020  0.063  0.038  0.024  0.147  0.014  0.010  0.018  ...
# 2      2  0.014  0.014  0.021  0.018  0.087  0.066  0.011  0.014  0.025  ...
# 3      3  0.034  0.016  0.067  0.019  0.044  0.045  0.004  0.094  0.035  ...
# 4      4  0.008  0.087  0.017  0.055  0.011  0.002  0.019  0.034  0.018  ...
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...  ...
# 995  995  0.026  0.041  0.033  0.159  0.010  0.098  0.010  0.032  0.052  ...
# 996  996  0.015  0.006  0.008  0.035  0.061  0.010  0.053  0.003  0.039  ...
# 997  997  0.020  0.059  0.020  0.041  0.024  0.002  0.002  0.063  0.022  ...
# 998  998  0.101  0.006  0.110  0.001  0.021  0.046  0.065  0.027  0.017  ...
# 999  999  0.008  0.182  0.017  0.020  0.026  0.016  0.034  0.014  0.010  ...
#
# ...

# %%
import numpy as np
#Check a random sample
s = 352

print(prevalences.iloc[s,:])

sample = pd.read_csv(os.path.join(path,'dev_labels',str(s)+'.txt'))
np.unique(sample.to_numpy().squeeze(),return_counts=True)[1]/1000
# Out:
# id    352.000
# 0       0.073
# 1       0.007
# 2       0.052
# 3       0.031
# 4       0.043
# 5       0.011
# 6       0.011
# 7       0.052
# 8       0.030
# 9       0.052
# 10      0.135
# 11      0.020
# 12      0.023
# 13      0.044
# 14      0.017
# 15      0.035
# 16      0.008
# 17      0.002
# 18      0.057
# 19      0.106
# 20      0.034
# 21      0.063
# 22      0.029
# 23      0.011
# 24      0.004
# 25      0.005
# 26      0.019
# 27      0.026
# Name: 352, dtype: float64
# array([0.073, 0.007, 0.052, 0.031, 0.043, 0.011, 0.011, 0.052, 0.03 ,
#        0.052, 0.135, 0.02 , 0.023, 0.044, 0.017, 0.035, 0.008, 0.002,
#        0.057, 0.106, 0.034, 0.063, 0.029, 0.011, 0.004, 0.005, 0.019,
#        0.026])
